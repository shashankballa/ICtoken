# %% [markdown]
# # Dependencies

# %%
pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.7/dist-packages (3.14.1)

# %%
from Crypto.PublicKey import RSA
from Crypto.Random import get_random_bytes
from Crypto.Cipher import AES, PKCS1_OAEP
from Crypto.Signature import pkcs1_15
from Crypto.Hash import SHA256
from time import time
from typing import List
import json
import enum
import hashlib
import copy
import sys

def hashStr(str_in):
  str_enc = str_in.encode()
  raw_hash = hashlib.sha256(str_enc)
  hex_hash = raw_hash.hexdigest()
  return hex_hash

def merkleRec(hashes):
  if len(hashes) == 0:
    return None
  if len(hashes) == 1:
    return hashStr(hashes[0])
  if len(hashes) == 2:
    return hashStr(hashes[0] + hashes[1])
  size = len(hashes)
  above_layer = []
  for i in range(0, size-1, 2):
    hash = hashStr(hashes[i] + hashes[i+1])
    above_layer.append(hash)
  if size % 2 == 1:
    above_layer.append(hashStr(hashes[-1]))
  return merkleRec(above_layer)

def merkleTree(l):
  strs = list(map(str, l))
  strs.sort()
  return merkleRec(strs)

# %% [markdown]
# # Owner

# %%
'''
Owner is any entity that can own an IC. This class constructs an owner object with all relevant information to participate in the ESC. 
'''
class Owner(object):
  def __init__(self, address: str, key: RSA.RsaKey):
      super().__init__
      self.address = address
      self.privateKey = key.export_key().hex()
      self.publicKey  = key.publickey().export_key().hex()
  
  def to_json_string(self):
    return json.dumps(self.__dict__, sort_keys = True)

  def encryptICkey(self, ICkey):
    pubKey = RSA.import_key(bytes.fromhex(self.publicKey))
    cipher_rsa = PKCS1_OAEP.new(pubKey)
    return cipher_rsa.encrypt(bytes.fromhex(ICkey)).hex()

  def decryptICkey(self, encICkey):
    privKey = RSA.import_key(bytes.fromhex(self.privateKey))
    cipher_rsa = PKCS1_OAEP.new(privKey)
    return cipher_rsa.decrypt(bytes.fromhex(encICkey)).hex()

  def ICkeySwap(self, encICkey, newOwner):
    ICkey = self.decryptICkey(encICkey)
    cipher_rsa = PKCS1_OAEP.new(RSA.import_key(bytes.fromhex(newOwner.publicKey)))
    return  cipher_rsa.encrypt(bytes.fromhex(ICkey)).hex()

  def signMessage(self, message):  
    key = RSA.import_key(bytes.fromhex(self.privateKey))
    h = SHA256.new(bytes.fromhex(message))
    signature = pkcs1_15.new(key).sign(h)
    return signature.hex()

  def verifySign(self, message, signature):
    key = RSA.import_key(bytes.fromhex(self.publicKey))
    h = SHA256.new(bytes.fromhex(message))
    try:
        pkcs1_15.new(key).verify(h, bytes.fromhex(signature))
        return True
    except (ValueError, TypeError):
        return False


'''
This class constructs the public image of the owner, how it is stored in the ICtracker Database. 
'''
class OwnerPublic(object):
  def __init__(self, Owner):
      self.address = Owner.address
      self.publicKey = Owner.publicKey
  
  def to_json_string(self):
    return json.dumps(self.__dict__, sort_keys = True)

  def verifySign(self, message, signature):
    key = RSA.import_key(bytes.fromhex(self.publicKey))
    h = SHA256.new(bytes.fromhex(message))
    try:
        pkcs1_15.new(key).verify(h, bytes.fromhex(signature))
        return True
    except (ValueError, TypeError):
        return False

# %%
ownr1 = Owner('A Devices', RSA.generate(2048))
ownr1Pub = OwnerPublic(ownr1)
ownr2 = Owner('IC Corp', RSA.generate(2048))
ownr2Pub = OwnerPublic(ownr2)

ICkey = get_random_bytes(16).hex()
ICkeyHash = hashStr(ICkey)

encICkey1 = ownr1.encryptICkey(ICkey)
decICkey1 = ownr1.decryptICkey(encICkey1)

encICkey2 = ownr1.ICkeySwap(encICkey1, ownr2Pub)
decICkey2 = ownr2.decryptICkey(encICkey2)
decICkey2 == ICkey
# Out:
# True

# %%
len(ICkeyHash)*4
# Out:
# 256

# %%
len(RSA.generate(2048).export_key().hex())
# Out:
# 3348

# %%
len(RSA.generate(2048).publickey().export_key().hex())
# Out:
# 900

# %%
message = get_random_bytes(16).hex()
signature = ownr1.signMessage(message)

ownr1Pub.verifySign(message, signature)
# Out:
# True

# %% [markdown]
# # ICtoken

# %%
'''
Contains all information unique to the IC that is stored as metadata for the icToken.
'''

class ICmetaData(object):
  def __init__(self, ECID, PID, SID, netHash, prevIdx, stage = None, status = None):
    self.ECID    = ECID
    self.PID     = PID
    self.SID     = SID
    self.netHash = netHash
    self.stage   = stage
    self.status  = status
    
    self.prevIdx = prevIdx
    self.version = 0

  def to_json_string(self):
    metaDataDict = self.__dict__.copy()
    metaDataDict.pop("version")
    metaDataDict.pop("prevIdx")
    return json.dumps(metaDataDict, sort_keys = True)


'''
The logic locking key (IC key) object. Stores the encryption of the IC key under 
the current owner's public key and a hash/digest of the plaint text key to ensure 
it is not changed along the way.
'''

class ICkeyPublic(object):
  def __init__(self, ICkey, owner: Owner):
    super().__init__()
    self.keyHash = hashStr(ICkey)
    self.keyEncr = owner.encryptICkey(ICkey)
      
  def to_json_string(self):
    return json.dumps(self.__dict__, sort_keys = True)

"""
An enumeration of the possible stages that a chip could be in
"""
class Stage(enum.Enum):
  fabrication = 1
  pcb_assembly = 2
  system_integrator = 3
  end_user = 4


class ICtoken(object):
  def __init__(self, metaData: ICmetaData, ICkeyPub: ICkeyPublic, ownerPub: OwnerPublic):

    self.metaData  = metaData    # all info unique to the IC
    self.ICkey     = ICkeyPub    # public image of the logic locking key: 1) hash digest for ID and 2) encrypted key
    self.owner     = ownerPub    # public image of the owner: 1) address and 2) Public Key

    icTokenStr  = self.metaData.to_json_string()
    icTokenStr += self.ICkey.to_json_string()
    icTokenStr += self.owner.to_json_string()

    self.trnsaxnID = hashStr(icTokenStr) # Indetifier for the transaction
    self.signature = bytes(6).hex()      # owner's signature for validation of the transaction

  def to_json_string(self):
    ICtokenDict = self.__dict__.copy()
    strOut      = self.metaData.to_json_string()
    ICtokenDict.pop("metaData")
    strOut     += self.ICkey.to_json_string()
    ICtokenDict.pop("ICkey")
    strOut     += self.owner.to_json_string()
    ICtokenDict.pop("owner")
    return strOut + json.dumps(ICtokenDict, sort_keys = True)

# %% [markdown]
# #Wallet

# %%
class Wallet(object):
  def __init__(self, owner: Owner):
    self.owner      = owner
    self.ICdb       = {}
  
  def enrollIC(self, ECID, ICkey):
    metaData  = ICmetaData(ECID, None, None,None, None, 
                           Stage.fabrication.value, 0)
    icToken   = ICtoken(metaData, 
                        ICkeyPublic(ICkey, self.owner), 
                        OwnerPublic(self.owner))
    icToken.signature  = self.owner.signMessage(icToken.trnsaxnID)
    return icToken

  def updateStage(self, ECID, stage, status):
    if ECID not in self.ICdb:
      print("Error: No IC with given ECID in Wallet")
      return None
    prevICtoken = copy.deepcopy(self.ICdb[ECID].ICtoken)
    prevICtoken.metaData.stage  = stage
    prevICtoken.metaData.status = status
    icToken     = ICtoken(prevICtoken.metaData,
                          prevICtoken.ICkey, 
                          prevICtoken.owner)
    icToken.signature = self.owner.signMessage(icToken.trnsaxnID)
    return icToken

  def updatePIDorSID(self, ECIDs, updatePID):

    merkleHash = merkleTree(ECIDs)

    icTokens = []
    owner_pub = None
    for ECID in ECIDs:
      if ECID not in self.ICdb:
        print("Error: No IC with given ECID in Wallet")
        return None  
      prevICtoken = copy.deepcopy(self.ICdb[ECID].ICtoken)
      if updatePID:
        prevICtoken.metaData.PID = merkleHash
      else:
        prevICtoken.metaData.SID = merkleHash
      icToken   = ICtoken(prevICtoken.metaData,
                          prevICtoken.ICkey, 
                          prevICtoken.owner)
      owner_pub = prevICtoken.owner
      icToken.signature = self.owner.signMessage(icToken.trnsaxnID)
      icTokens.append(icToken)
    return icTokens
  
  def transferIC(self, ECID, newOwner: OwnerPublic):
    if ECID not in self.ICdb:
      print("Error: No IC with this ECID# in Wallet")
      return None
    prevICtoken       = copy.deepcopy(self.ICdb[ECID].ICtoken)
    newKey            = copy.deepcopy(prevICtoken.ICkey)
    newKey.keyEncr     = self.owner.ICkeySwap(newKey.keyEncr, newOwner)
    icToken           = ICtoken(prevICtoken.metaData, newKey, newOwner)
    icToken.signature = self.owner.signMessage(icToken.trnsaxnID)
    return icToken

  def updateICdb(self, icTracker):
    try:
      self.ICdb = icTracker.ICdb[self.owner.address]
      return self.ICdb
    except (ValueError, TypeError, AttributeError):
      return None

# %% [markdown]
# # Blockchain

# %%
class Block(object):
  def __init__(self, metaData: ICmetaData, ICkey: ICkeyPublic, owner: OwnerPublic, index = None, prevHash = None):

    # Block Header
    self.ICtoken = ICtoken(metaData, ICkey, owner)

    # Blockchain attributes
    self.index     = index
    self.prevHash  = prevHash
    self.timestamp = time()
  
  def to_json_string(self):
    blockDict = self.__dict__.copy()
    strOut  = self.ICtoken.to_json_string()
    blockDict.pop("ICtoken")
    return strOut + json.dumps(blockDict, sort_keys = True)

# %%
def genGenesisBlock():
  genesis_metaD = ICmetaData(bytes(4).hex(), None, None, None, None)
  genesis_owner = Owner('No(o)ne', RSA.generate(2048))
  genesis_ICkey = ICkeyPublic(bytes(4).hex(), genesis_owner)
  genesis_ICkey.keyHash = bytes(4).hex()
  genesis_ICkey.keyEncr = bytes(4).hex()
  genesis_owner = OwnerPublic(genesis_owner)
  genesis_owner.publicKey = bytes(4).hex()
  return Block(genesis_metaD, genesis_ICkey, genesis_owner, 0)

"""
The basic blockchain structure
"""
class Blockchain(object):
  def __init__(self):
    self.chain = []
    genesis_block = genGenesisBlock()
    self.chain.append(genesis_block)

  @property
  def last_block(self):
    return self.chain[-1]


  """
  Adds a new block to the blockchain

  return: returns the block added or None on failures
  """
  def new_block(self, block : Block):
    # Check that we only add Block objects
    if not type(block) is Block:
      print('Error: attempted to add non-Block object')
      return None

    blockCopy = copy.deepcopy(block)

    # Gets hash of the previous block
    blockCopy.prevHash = hashStr(self.last_block.to_json_string())
    # Set the index of this block
    blockCopy.index = len(self.chain)
    # Set the timestamp of this block on the blockchain
    blockCopy.timestamp = time()

    self.chain.append(blockCopy)
    return blockCopy


  """
  Formats the contents of the blockchain in a pretty string
  """
  def chain_to_string(self):
    res = '['
    for block in self.chain:
      res += '\n\t' + block.to_json_string() + ''
    res += '\n]'
    return res

# %% [markdown]
# # ICtracker

# %%
"""
Uses the blockchain to implement ICtracker
"""
class ICtracker(object):
  def __init__(self):
    self.blockchain = Blockchain()
    self.ownersdb = {}
    self.ecid_to_index = {}
    self.ICdb = {}

  """
  Gets the most current block with a given ECID
  """
  def get_ECID_block(self, ECID):
    if ECID in self.ecid_to_index:
      index = self.ecid_to_index[ECID]
      return self.blockchain.chain[index], index
    return None

  """
  Gets the histroy of an ECID on blockchain
  """
  def get_ECID_history(self, ECID):
    if ECID not in self.ecid_to_index:
      return None
    history = []
    index = self.ecid_to_index[ECID]
    block = self.blockchain.chain[index]
    blockCopy = copy.deepcopy(block)
    history.append(blockCopy)
    while block.ICtoken.metaData.prevIdx is not None:
      block = self.blockchain.chain[block.ICtoken.metaData.prevIdx]
      blockCopy = copy.deepcopy(block)
      history.append(blockCopy)
    return history

  def enrollOwner(self, owner: OwnerPublic):
    if owner.address in self.ownersdb:
      print('Error: Owner already enrolled')
      return None
    self.ownersdb[owner.address] = owner
    self.ICdb[owner.address] = {}
    return True


  def verifyTransaxn(self, owner: OwnerPublic, icToken = None):
    if owner.address not in self.ownersdb:
      print('Error: Owner not authorized')
      return None
    if icToken is not None:
      if not self.ownersdb[owner.address].verifySign(icToken.trnsaxnID, icToken.signature):
        print('Error: Owner verification failed')
        return None
    return owner.address


  def enrollIC(self, icToken: ICtoken):

    if icToken.metaData.ECID in self.ecid_to_index:
      print('Error: cannot enroll an already enrolled ECID')
      return None

    ownerID = self.verifyTransaxn(icToken.owner, icToken)
    if ownerID is None:
      print('Error: unable to verify owner')
      return None

    PIDcheck    = (icToken.metaData.PID == None)
    SIDcheck    = (icToken.metaData.SID == None)
    stageChk    = (icToken.metaData.stage == Stage.fabrication.value)
    statusChk   = (icToken.metaData.status  == 0)
    prevIdxChk  = (icToken.metaData.prevIdx == None)
    versionChk  = (icToken.metaData.version == 0)
    if (PIDcheck + SIDcheck + stageChk + statusChk + prevIdxChk + versionChk) < 6:
      print('Error: incorrect metadata for Enrollment')
      return None

    metaDataCopy = copy.deepcopy(icToken.metaData)
    ICkeyCopy    = copy.deepcopy(icToken.ICkey)
    ownerCopy    = copy.deepcopy(icToken.owner)
    block        = Block(metaDataCopy, ICkeyCopy, ownerCopy)
    block.ICtoken.trnsaxnID = copy.deepcopy(icToken.trnsaxnID)
    block.ICtoken.signature = copy.deepcopy(icToken.signature)

    res = self.blockchain.new_block(block)

    if res is None:
      print('Error: failed adding block')
      return None

    self.ecid_to_index[res.ICtoken.metaData.ECID] = res.index
    self.ICdb[ownerID][res.ICtoken.metaData.ECID] = res

    return res

  def updateStage(self, icToken: ICtoken):

    if icToken.metaData.ECID not in self.ecid_to_index:
      print('Error: chip not enrolled!')
      return None

    prevBlock = self.get_ECID_block(icToken.metaData.ECID)[0]
    
    ownerID = self.verifyTransaxn(prevBlock.ICtoken.owner, icToken)
    if ownerID is None:
      return None

    if  icToken.metaData.stage <= prevBlock.ICtoken.metaData.stage:
      if  icToken.metaData.status <= prevBlock.ICtoken.metaData.status:
        print('Error: Can\'t rollback stage!')
        return None

    newBlock = copy.deepcopy(prevBlock)
    newBlock.ICtoken.metaData.stage    =  icToken.metaData.stage
    newBlock.ICtoken.metaData.status   =  icToken.metaData.status
    newBlock.ICtoken.metaData.prevIdx  =  self.ecid_to_index[icToken.metaData.ECID]
    newBlock.ICtoken.metaData.version +=  1 
    newBlock.ICtoken.trnsaxnID = icToken.trnsaxnID
    newBlock.ICtoken.signature = icToken.signature
    
    res = self.blockchain.new_block(newBlock)
    if res is None:
      print('Error: failed adding block')

    self.ecid_to_index[res.ICtoken.metaData.ECID] = res.index
    self.ICdb[ownerID][res.ICtoken.metaData.ECID] = res
    
    return res

  def updatePIDorSID(self, icTokens: list):
    can_add_PID = True
    can_add_SID = True
    ECIDs = []
    for icToken in icTokens:
      metaData = icToken.metaData
      ICkeyPublic = icToken.ICkey
      ECID = metaData.ECID
    
      if icToken.metaData.ECID not in self.ecid_to_index:
        print('Error: chip not enrolled!')
        return None
      ECIDs.append(ECID)

      prevICtoken = self.get_ECID_block(ECID)[0].ICtoken
      
      ownerID = self.verifyTransaxn(prevICtoken.owner, icToken)
      if ownerID is None:
        return None

      if prevICtoken.metaData.stage != Stage.pcb_assembly.value or not prevICtoken.metaData.PID is None:
        can_add_PID = False
      if prevICtoken.metaData.stage != Stage.system_integrator.value or not prevICtoken.metaData.SID is None:
        can_add_SID = False
    
    if not (can_add_PID or can_add_SID):
      print('Error: cannot add PID or SID')
      return None

    output_hash = merkleTree(ECIDs)

    res_list = []
    for icToken in icTokens:
      prevBlock = self.get_ECID_block(icToken.metaData.ECID)[0]
      newBlock = copy.deepcopy(prevBlock)
      if can_add_PID:
        newBlock.ICtoken.metaData.PID = output_hash
      else:
        newBlock.ICtoken.metaData.SID = output_hash
      newBlock.ICtoken.metaData.prevIdx  = self.ecid_to_index[icToken.metaData.ECID]
      newBlock.ICtoken.metaData.version += 1
      newBlock.ICtoken.trnsaxnID = icToken.trnsaxnID
      newBlock.ICtoken.signature = icToken.signature
      res = self.blockchain.new_block(newBlock)
      if res is None:
        print('Error: failed adding block')
      self.ecid_to_index[res.ICtoken.metaData.ECID] = res.index
      self.ICdb[ownerID][res.ICtoken.metaData.ECID] = res
      res_list.append(res)
    return res_list

  def transferIC(self, icToken: dict):

    if icToken.metaData.ECID not in self.ecid_to_index:
      print('Error: chip not enrolled!')
      return None
    
    newOwnerID  = self.verifyTransaxn(icToken.owner)
    if newOwnerID is None:
      print("\tNew Owner not autherized!")
      return None

    prevBlock = self.get_ECID_block(icToken.metaData.ECID)[0]
    oldOwnerID = self.verifyTransaxn(prevBlock.ICtoken.owner, icToken)
    if oldOwnerID is None:
      print('\toldOwner verification failed')
      return None

    newBlock = copy.deepcopy(prevBlock)
    newBlock.ICtoken.metaData.prevIdx  = self.ecid_to_index[icToken.metaData.ECID]
    newBlock.ICtoken.metaData.version += 1
    newBlock.ICtoken.owner     = icToken.owner
    newBlock.ICtoken.ICkey     = icToken.ICkey
    newBlock.ICtoken.trnsaxnID = icToken.trnsaxnID
    newBlock.ICtoken.signature = icToken.signature
    res = self.blockchain.new_block(newBlock)
    if res is None:
      print('Error: failed adding block')

    self.ecid_to_index[res.ICtoken.metaData.ECID] = res.index
    self.ICdb[oldOwnerID].pop(res.ICtoken.metaData.ECID)
    self.ICdb[newOwnerID][res.ICtoken.metaData.ECID] = res
    return res

# %%
def genRandECID(numBytes):
  return get_random_bytes(numBytes).hex()

# %%
icTracker = ICtracker()
wallet1 = Wallet(ownr1)

# Testing Enroll owner
icTracker.enrollOwner(ownr1Pub)
# Out:
# True

# %%
# generating random ECID and ICkey for testing

ECID1      = genRandECID(6)
ICkey1     = genRandECID(6)

# %%
# Testing Enrollment of new IC in wallet

icToken1 = wallet1.enrollIC(ECID1, ICkey1)

# %%
sys.getsizeof(icToken1)
# Out:
# 64

# %%
len(icToken1.ICkey.keyEncr)/2
# Out:
# 256.0

# %%
# Testing Enrollment of new IC in ICtracker

res = icTracker.enrollIC(icToken1)

print("Owner1's ICtokens :\n", wallet1.updateICdb(icTracker))
# Out:
# Owner1's ICtokens :
#  {'93838f111967': <__main__.Block object at 0x7fdb530c8190>}

# %%
# Testing transfer of IC to unenrolled Owner

icToken2 = wallet1.transferIC(icToken1.metaData.ECID, ownr2Pub)

res = icTracker.transferIC(icToken2)
# Out:
# Error: Owner not authorized
# 	New Owner not autherized!

# %%
# Enrolling new owner into ICtracker

wallet2 = Wallet(ownr2)

icTracker.enrollOwner(ownr2Pub)
# Out:
# True

# %%
# Testing transfer of IC to an enrolled Owner

res = icTracker.transferIC(icToken2)

print("Owner1's ICtokens :\n", wallet1.updateICdb(icTracker))
print("\nOwner2's ICtokens :\n",wallet2.updateICdb(icTracker))
# Out:
# Owner1's ICtokens :
#  {}
#
# Owner2's ICtokens :
#  {'93838f111967': <__main__.Block object at 0x7fdb530cbed0>}

# %% [markdown]
# #Testing

# %%
from numpy import random

# Test Params: number of total users and number of total chips
num_ownersdb = 2
num_chips = 100

# Our own mapping of ownersdb to data for testing purposes
test_ownersdb = {}

# Our own mapping of ECIDs to current owner for testing purposes
test_ecid_to_data = {}


def verify_blockchain_correctness(ownersdb, ecid_to_data, supply_chain):
  for ecid in ecid_to_data:
    block, idx = supply_chain.get_ECID_block(ecid)
    if block is None:
      assert False, ('ERROR: Did not find block with ECID ' + str(ecid) + ' in blockchain')
    test_owner_index = ecid_to_data[ecid]['owner_num']
    
    # Assert owner is correct
    assert ownersdb[test_owner_index]['owner_pub'].address == block.ICtoken.owner.address, ('ERROR: Incorrect address: ECID ' + str(ecid) + ' is owned by ' + ownersdb[test_owner_index]['owner_pub'].address + ', but blockchain has ' + block.ICtoken.owner.address)
    assert ownersdb[test_owner_index]['owner_pub'].publicKey == block.ICtoken.owner.publicKey, ('ERROR: Incorrect Public Key: ECID ' + str(ecid) + ' is owned by ' + ownersdb[test_owner_index]['owner_pub'].address + ', but blockchain has ' + block.ICtoken.owner.address)

    # Assert metadata is correct
    assert ecid_to_data[ecid]['SID'] == block.ICtoken.metaData.SID, ('ERROR: ECID ' + str(ecid) + ' has SID ' + str(ecid_to_data[ecid]['SID']) + ', but blockchain has ' + str(block.ICtoken.metaData.SID))
    assert ecid_to_data[ecid]['PID'] == block.ICtoken.metaData.PID, ('ERROR: ECID ' + str(ecid) + ' has PID ' + str(ecid_to_data[ecid]['PID']) + ', but blockchain has ' + str(block.ICtoken.metaData.PID))
    assert ecid_to_data[ecid]['stage'] == block.ICtoken.metaData.stage, ('ERROR: ECID ' + str(ecid) + ' has stage ' + str(ecid_to_data[ecid]['stage']) + ', but blockchain has ' + str(block.ICtoken.metaData.stage))
    assert ecid_to_data[ecid]['status'] == block.ICtoken.metaData.status, ('ERROR: ECID ' + str(ecid) + ' has status ' + str(ecid_to_data[ecid]['status']) + ', but blockchain has ' + str(block.ICtoken.metaData.status))
    assert ecid_to_data[ecid]['version'] == block.ICtoken.metaData.version, ('ERROR: ECID ' + str(ecid) + ' has version ' + str(ecid_to_data[ecid]['version']) + ', but blockchain has ' + str(block.ICtoken.metaData.version))

# Initialize ICtracker
icTracker = ICtracker()

# Init ownersdb
for i in range(num_ownersdb):
  ownr = Owner('Owner ' + str(i), RSA.generate(2048))
  ownr_pub = OwnerPublic(ownr)
  wallet = Wallet(ownr)
  test_ownersdb[i] = {'owner': ownr, 'owner_pub': ownr_pub, 'wallet': wallet}
  icTracker.enrollOwner(ownr_pub)

# Init Chips, Assign to ownersdb, and ownersdb Enroll Chips to Blockchain
for i in range(num_chips):
  ownr_num = random.randint(0, num_ownersdb)
  ownr = test_ownersdb[ownr_num]['owner']
  ownr_pub = test_ownersdb[ownr_num]['owner_pub']
  ownr_wallet = test_ownersdb[ownr_num]['wallet']
  logic_lock_key = get_random_bytes(16).hex()
  icToken = ownr_wallet.enrollIC(i, logic_lock_key)
  res = icTracker.enrollIC(icToken)
  ownr_wallet.updateICdb(icTracker)
  test_ecid_to_data[i] = {'owner_num': ownr_num,
                          'stage': Stage.fabrication.value,
                          'status': 0,
                          'version': 0,
                          'PID': None,
                          'SID': None}

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Enrolling Chips Successful\n\n")
# Out:
# Enrolling Chips Successful

# %%
# Update a Chip Stage
ownr_num = random.randint(0, num_ownersdb)
owned_chips_cnt = len(test_ownersdb[ownr_num]['wallet'].ICdb)
while owned_chips_cnt == 0:
  ownr_num = random.randint(0, num_ownersdb)
  owned_chips_cnt = len(test_ownersdb[ownr_num]['wallet'].ICdb)

ownr_wallet = test_ownersdb[ownr_num]['wallet']
ecid_of_chip_to_update = 0
for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  break
icToken = ownr_wallet.updateStage(ecid_of_chip_to_update, Stage.fabrication.value, 1)
res = icTracker.updateStage(icToken)
ownr_wallet.updateICdb(icTracker)
test_ecid_to_data[ecid_of_chip_to_update]['status'] = 1
test_ecid_to_data[ecid_of_chip_to_update]['version'] = 1

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Updating Single Chip Stage Successful\n\n")
# Out:
# Updating Single Chip Stage Successful

# %%
# Update Stage of Multiple Chips
ownr_num = random.randint(0, num_ownersdb)
owned_chips_cnt = len(test_ownersdb[ownr_num]['wallet'].ICdb)
while owned_chips_cnt == 0:
  ownr_num = random.randint(0, num_ownersdb)
  owned_chips_cnt = len(test_ownersdb[ownr_num]['wallet'].ICdb)

ownr_wallet = test_ownersdb[ownr_num]['wallet']
for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  icToken = ownr_wallet.updateStage(ecid_of_chip_to_update, Stage.pcb_assembly.value, 0)
  res = icTracker.updateStage(icToken)
  ownr_wallet.updateICdb(icTracker)
  test_ecid_to_data[ecid_of_chip_to_update]['stage'] = Stage.pcb_assembly.value
  test_ecid_to_data[ecid_of_chip_to_update]['status'] = 0
  test_ecid_to_data[ecid_of_chip_to_update]['version'] += 1

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Updating Stage of Multiple Chips Successful\n\n")
# Out:
# Updating Stage of Multiple Chips Successful

# %%
# Add PID to Chips in PCB Assembly Stage
ecid_list = []

for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  ecid_list.append(ecid_of_chip_to_update)

pid_hash = merkleTree(ecid_list)

for x in ownr_wallet.ICdb:
  test_ecid_to_data[x]['PID'] = pid_hash
  test_ecid_to_data[x]['version'] += 1

icToken = ownr_wallet.updatePIDorSID(ecid_list, True)
res_list = icTracker.updatePIDorSID(icToken)
for res in res_list:
  ownr_wallet.updateICdb(icTracker)

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Updating PID Successful\n\n")
# Out:
# Updating PID Successful

# %%
# Moving Back Stage Unsuccessful
ownr_wallet = test_ownersdb[ownr_num]['wallet']
for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  icToken = ownr_wallet.updateStage(ecid_of_chip_to_update, Stage.fabrication.value, 0)
  res = icTracker.updateStage(icToken)
  ownr_wallet.updateICdb(icTracker)

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Verified Moving Back Stage Unsuccessful\n\n")
# Out:
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Error: Can't rollback stage!
# Verified Moving Back Stage Unsuccessful

# %%
# Adding PID to Block with Existing PID Unsuccessful
icToken = ownr_wallet.updatePIDorSID(ecid_list, True)
res_list = icTracker.updatePIDorSID(icToken)
assert res_list is None 

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Verified Updating PID Unsuccessful\n\n")
# Out:
# Error: cannot add PID or SID
# Verified Updating PID Unsuccessful

# %%
# Check the history of blocks
for x in ownr_wallet.ICdb:
  history = icTracker.get_ECID_history(x)
  assert len(history)-1 == test_ecid_to_data[x]['version']

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Check History of ECID with Version\n\n")
# Out:
# Check History of ECID with Version

# %%
# Move blocks to system integration
for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  icToken = ownr_wallet.updateStage(ecid_of_chip_to_update, Stage.system_integrator.value, 0)
  res = icTracker.updateStage(icToken)
  ownr_wallet.updateICdb(icTracker)
  test_ecid_to_data[ecid_of_chip_to_update]['stage'] = Stage.system_integrator.value
  test_ecid_to_data[ecid_of_chip_to_update]['status'] = 0
  test_ecid_to_data[ecid_of_chip_to_update]['version'] += 1

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Updating Stage of Multiple Chips Successful\n\n")
# Out:
# Updating Stage of Multiple Chips Successful

# %%
# Test Transferring

# First create a new user
ownr_new = Owner('Owner X', RSA.generate(2048))
ownr_new_pub = OwnerPublic(ownr_new)
wallet_new = Wallet(ownr_new)


# Transferring to unenrolled owner should fail
ecid_of_chip_to_update = 0
for x in ownr_wallet.ICdb:
  ecid_of_chip_to_update = x
  break
icToken = ownr_wallet.transferIC(x, ownr_new_pub)
res = icTracker.transferIC(icToken)
verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print('Verified Transferring to Unenrolled Owner Fails\n\n')

# Transferring to enrolled owner sould succeed
icTracker.enrollOwner(ownr_new_pub)
test_ownersdb[num_ownersdb] = {'owner': ownr_new, 'owner_pub': ownr_new_pub, 'wallet': wallet_new}
ICdb_copy = copy.deepcopy(ownr_wallet.ICdb)
for x in ICdb_copy:
  ecid_of_chip_to_update = x
  icToken = ownr_wallet.transferIC(ecid_of_chip_to_update, ownr_new_pub)
  res = icTracker.transferIC(icToken)
  ownr_wallet.updateICdb(icTracker)
  wallet_new.updateICdb(icTracker)
  test_ecid_to_data[x]['version'] += 1
  test_ecid_to_data[x]['owner_num'] = num_ownersdb

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print('Verified Transferring to Enrolled Owner Succeeds')
# Out:
# Error: Owner not authorized
# 	New Owner not autherized!
# Verified Transferring to Unenrolled Owner Fails
#
#
# Verified Transferring to Enrolled Owner Succeeds

# %%
# New owner gets enrolls more chips and combines all to add SID
for i in range(num_chips, num_chips+5):
  logic_lock_key = get_random_bytes(16).hex()
  icToken = wallet_new.enrollIC(i, logic_lock_key)
  res = icTracker.enrollIC(icToken)
  wallet_new.updateICdb(icTracker)
  test_ecid_to_data[i] = {'owner_num': num_ownersdb, 'stage': Stage.fabrication.value, 'status': 0, 'version': 0, 'PID': None, 'SID': None}

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print('Verified New Owner Adding More Chips\n\n')


# Gets these chips to PCB assembly
for x in range(num_chips, num_chips+5):
  ecid_of_chip_to_update = x
  icToken = wallet_new.updateStage(ecid_of_chip_to_update, Stage.pcb_assembly.value, 0)
  res = icTracker.updateStage(icToken)
  wallet_new.updateICdb(icTracker)
  test_ecid_to_data[ecid_of_chip_to_update]['stage'] = Stage.pcb_assembly.value
  test_ecid_to_data[ecid_of_chip_to_update]['status'] = 0
  test_ecid_to_data[ecid_of_chip_to_update]['version'] += 1

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print('Verified New Owner Updating Stage\n\n')


# Adds PID to new chips
ecid_list = []
for x in range(num_chips, num_chips+5):
  ecid_of_chip_to_update = x
  ecid_list.append(ecid_of_chip_to_update)

pid_hash = merkleTree(ecid_list)

for x in range(num_chips, num_chips+5):
  test_ecid_to_data[x]['PID'] = pid_hash
  test_ecid_to_data[x]['version'] += 1

icToken = wallet_new.updatePIDorSID(ecid_list, True)
res_list = icTracker.updatePIDorSID(icToken)
wallet_new.updateICdb(icTracker)

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Verified New Owner Adding PID Successful\n\n")


# Check adding SID currently unsuccessful
ecid_list = []
for x in range(num_chips, num_chips+5):
  ecid_of_chip_to_update = x
  ecid_list.append(ecid_of_chip_to_update)

pid_hash = merkleTree(ecid_list)

icToken = wallet_new.updatePIDorSID(ecid_list, False)
res_list = icTracker.updatePIDorSID(icToken)
wallet_new.updateICdb(icTracker)

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Verified Adding SID Unsuccessful in Fab Stage\n\n")

# Move to system integration stage
for x in range(num_chips, num_chips+5):
  ecid_of_chip_to_update = x
  icToken = wallet_new.updateStage(ecid_of_chip_to_update, Stage.system_integrator.value, 0)
  res = icTracker.updateStage(icToken)
  wallet_new.updateICdb(icTracker)
  test_ecid_to_data[ecid_of_chip_to_update]['stage'] = Stage.system_integrator.value
  test_ecid_to_data[ecid_of_chip_to_update]['status'] = 0
  test_ecid_to_data[ecid_of_chip_to_update]['version'] += 1

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print('Verified New Owner Updating Stage\n\n')


# New owner combines all chips in system integration
ecid_list = []
for x in wallet_new.ICdb:
  ecid_of_chip_to_update = x
  ecid_list.append(ecid_of_chip_to_update)

sid_hash = merkleTree(ecid_list)

for x in wallet_new.ICdb:
  test_ecid_to_data[x]['SID'] = sid_hash
  test_ecid_to_data[x]['version'] += 1

icToken = wallet_new.updatePIDorSID(ecid_list, False)
res_list = icTracker.updatePIDorSID(icToken)
wallet_new.updateICdb(icTracker)

verify_blockchain_correctness(test_ownersdb, test_ecid_to_data, icTracker)
print("Updating SID Successful\n\n")
# Out:
# Verified New Owner Adding More Chips
#
#
# Verified New Owner Updating Stage
#
#
# Verified New Owner Adding PID Successful
#
#
# Error: cannot add PID or SID
# Verified Adding SID Unsuccessful in Fab Stage
#
#
# Verified New Owner Updating Stage
#
#
# Updating SID Successful

# %%
print(icTracker.blockchain.chain_to_string())
# Out:
# [
# 	{"ECID": "00000000", "PID": null, "SID": null, "netHash": null, "stage": null, "status": null}{"keyEncr": "00000000", "keyHash": "00000000"}{"address": "No(o)ne", "publicKey": "00000000"}{"signature": "000000000000", "trnsaxnID": "58724593f5930adf4d33e7a14e618c7ddf6db9d81e38773cd00e7e377a62869d"}{"index": 0, "prevHash": null, "timestamp": 1652703339.540596}
# 	{"ECID": 0, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "2b51d5ed0004d0187a2411d409735253e5045f87c1d858a3068af16cf01b3b6f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "fb2e11e79c3440a0ce1b9d7a5afdbbbe7b0c39d06f7a1a3729ac6efbf585cfa6"}{"index": 1, "prevHash": "ce9c4774b526f7e225b1ee00cd0033983baf501c3a96000f179e101c7fe9608c", "timestamp": 1652703341.30346}
# 	{"ECID": 1, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "6900de6fc06868760e936d10515704ff5d921dc4b58caf615633cd0e0728673d"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4702c45655bf82d01cf2eede159900393a7e76623e2c1a41b8dff2b0c57ba6f0"}{"index": 2, "prevHash": "8762c0e22e378d4f58a2e4d4a00280766f60f8077b6ef533448649bc7f7c3320", "timestamp": 1652703341.4236825}
# 	{"ECID": 2, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "06873303e278c3ea9d125d75b183f73e38640272b70e758081c08f0cc97355fc"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1984183fdb05239a3f7f771d48ca53219ea0937963a43bd5bdd224e989eccd62"}{"index": 3, "prevHash": "88b9a266661f4cdbe3a4d2d65e98f50498798afe7ccc93bb8e92098e84d081b5", "timestamp": 1652703341.5669863}
# 	{"ECID": 3, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "207f5f7fd64fc3e3bc1f8591a66f9da23f1fcc54e6b917f44c4c6709e82b7e90"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0916bfed1c2f5f124d9be4252a5ea9141a54eff1d2e2c7b741063455b7ea743d"}{"index": 4, "prevHash": "d606a75f55f60f078ab741b108963e140f32d1cc69483f82c204e658cbf568e5", "timestamp": 1652703341.6940396}
# 	{"ECID": 4, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "3e35c4226a44d1d27e96a9420481e7c772102761080557b61ebc81e814bdd20d"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a4c6dc7bf92a463097e6c6e83f6f1967b7f635ceef63980f702f40504ba495f8"}{"index": 5, "prevHash": "00a9bb4cec00a18eec04089ba7b4bdea5ca8925787bb3033c32c6ae946b2f27d", "timestamp": 1652703341.8498228}
# 	{"ECID": 5, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "07861ad807e4d6a652ef7221211dd0fcab7e72ae58cf961c725a12667988f04a"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "6528abd5a2dfefe82e7d028c5dc7f9ee7c6f23f6b4e7de380ee1bf011a051b03"}{"index": 6, "prevHash": "fac2ad30a62c731c84e46b544e144ba71fc7a2987867866fe85b46e1de725905", "timestamp": 1652703341.9142554}
# 	{"ECID": 6, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "682a4bfe45e0ed1dc289d552e60687e476e7b84e0c19fe5532926b28c191faba"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "f690c35fbf21b0658526a1c0f652aeedfe86627da13b36f5a2bcae48671a740d"}{"index": 7, "prevHash": "5583a8f1a6e83422b6c3a0b5333b18887ca8f78121ba22dc029d4e0aef296ec5", "timestamp": 1652703341.9807255}
# 	{"ECID": 7, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "c475df1a6a0d6c3f8e5426cb53cd3bb84525bb1277778eb158c6f9e41620c0a5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "28e33a8a7510538b2b32c1f6a48fbe811eaaa8d1a35ea0842cc05a78ccc4a657"}{"index": 8, "prevHash": "aff8e1dc21aaf4f31e5e7f1312da25bf5d15480179ee546249b4aa70d67ca9d3", "timestamp": 1652703342.043744}
# 	{"ECID": 8, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "ec3163cd27ed4a332766cc7eb99e1cc377c26d7e296926e42cf6609f3f075ed8"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "9269bc57409a353f2e1b0071acc42c44737f6a0eda74590d71c799b286263b56"}{"index": 9, "prevHash": "431b45bf3c6a45e7ea6b99a18cba389ab2a9f114e8e1e48a05cad168bf47dd63", "timestamp": 1652703342.1148295}
# 	{"ECID": 9, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "e6367c4d4b90773624c56ebdbf4d2e92b5b8c548e581de2ebff3c31d597ef065"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "866bdbe03e7fc80dc11510f440c9fe900dfc203b7c33d715a760450b31de661c"}{"index": 10, "prevHash": "110b2f3ea69e1317e1ca08f1c502f3045abfec5f395f026166ac2672266f3445", "timestamp": 1652703342.1791327}
# 	{"ECID": 10, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "f8cc026c9deb410fa2e1776366ba55a5650df9b73727c26a5f6b784bf88a98cc"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "82327bc768755ce288ca10a04267ccc4573fcbd0ecee674c9651cfc8e9108928"}{"index": 11, "prevHash": "0256d9c7447098444b986dd7957d9d3689bb6e17ef846f8442ab8ac5634182c8", "timestamp": 1652703342.2481701}
# 	{"ECID": 11, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "bcc3bb25d9b9c974efb9c503c58b7c539d3df48d94888aed0d08cfa0d83a202f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "ec53cbf9d2439d0094632330907328c5294f87cb4a01fe1340a284f96111a557"}{"index": 12, "prevHash": "0c97a87cc27fb8a0b0d5ea04e6cefb7cca3a1a0cfb6c8d70ada014e23dbe1a80", "timestamp": 1652703342.3114867}
# 	{"ECID": 12, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "1a1c25547f1736d948519e947647b425d322b709269cf95e0572d1566734c96a"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "ff861e7bc93c872f9914e7a6b4e0cf43b9a60fae0272290ce67da3ecc3d3f664"}{"index": 13, "prevHash": "d8a6ed13731035ade06cffc52eb2d9603ffa867c331ee41beba97198b69eba94", "timestamp": 1652703342.3752632}
# 	{"ECID": 13, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "f42575a90aac645e8d737cef9ab9747925bfddea471aea09344a596ff2bd0181"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "23402b23a825b7eaba7270e94c5bae4b4ee57d1dcfcfb21c9e64968ea7688f09"}{"index": 14, "prevHash": "fa060769a5311697a7ea8fba5f0ec7527a3db76ccd111898a61983fb66b99a09", "timestamp": 1652703342.4402142}
# 	{"ECID": 14, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "62edf8f647999d138a940cb9a10041d826b40a44fe3bd5b9b3a1dae0d2bca3ef"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e0e5986a28c80cbc892f02f85b5c02aeb00ec46466fd9d9609526f1927cd6abf"}{"index": 15, "prevHash": "e5f6da3e8d61a31c0af7c82da2b9e8c2ba89fe39931bc46ca9f954dc9addf40a", "timestamp": 1652703342.512177}
# 	{"ECID": 15, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "24094a95db5072f2d373c95e2efbe3c5edca31c5a229a7f3eae920935a5e653d"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "dbce6cd5fea692544eee7f11adcc216a17b233aa8505ec4a63b15cfcacb3550b"}{"index": 16, "prevHash": "b8d02c75433f8bc11b900f209337ef8ddebed27f18c8e78de59af1f488049859", "timestamp": 1652703342.5763016}
# 	{"ECID": 16, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "1ebf4f045d952b565b053598fd9c79e8d2d3fb30f6f2a18f717d2b83401b4a34"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "81d120b9f1ab1ccc32ef3a40bc3e7cc1b1d06c448910e8e7e44313af6b26e0de"}{"index": 17, "prevHash": "11c43359b1974e9f83dd52758895c78e411bd175a05d20c09a34fc96be55b5c0", "timestamp": 1652703342.6416254}
# 	{"ECID": 17, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a5f5381b0bf3d6129c677ec08039642a8d9da60ee9741e12539dc42ece5a6222"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "9d685d90c969faa2fccbe07033c2ba2c2f6f79d5f9b0be906a25037dc0666501"}{"index": 18, "prevHash": "3d9d022fe4b9c426db42bc27e2e8839b98e90700c6738b32c62a897eed000967", "timestamp": 1652703342.7076166}
# 	{"ECID": 18, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "446c6ffeabad3eca0a0274f035b6038b9e3095a57e34462f27bf1d4af3856e03"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "f42de5a9660849b246f00271331540aec2c54fa881dfa1490733d2f56a8d1f16"}{"index": 19, "prevHash": "7b2d3a96b76b594328947715fc745d3e66e5444a13b0b0bcd543e8ff47741bd2", "timestamp": 1652703342.7775161}
# 	{"ECID": 19, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "574673c818459e5b33e666a21ab640937e706b2ecaa82b687896f37990349cda"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b2a15a8cd2b980bc71f2c60ba488d2395b1d65adf3dbd2ddb739b72d746f28ad"}{"index": 20, "prevHash": "b240969e4b43bcb11395759f8e09937232c5ac45983a92596027a7e2d611b566", "timestamp": 1652703342.8451009}
# 	{"ECID": 20, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "b5fc0005164468d3ff66573652ee919ecb11bc78dab3aca555b9fc28e81b1479"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "53de516f61f437609e43bcf0534bc174346f172c516fd13692f56ff9e446f12d"}{"index": 21, "prevHash": "72bbe3cae07a2065f58425f325a94d5ce9b5c57c1b94a0f4bccab997166a7c39", "timestamp": 1652703342.9122295}
# 	{"ECID": 21, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "b18ee6c775ec566c4b73d120f49e65db1f742ede22ff92c66e6fcd041d46d95b"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "dc32ab4f457a3589e800f1cb853be5965b9dd5087a01b0a4ece2b244c77cd7bd"}{"index": 22, "prevHash": "96f5851b19b9d664f45e97fedc8a6c2b4377802d2f60be0818bc66f9b8b58e28", "timestamp": 1652703342.978687}
# 	{"ECID": 22, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "3dce6a59e77bf87ba3fb55b10465f7c6ecc79cdee5559d196b1843073a48a757"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "d06fa9c3592f12e85d2c66c88bbd6bd07f9a9f321c45eb2d88a156882b071fcd"}{"index": 23, "prevHash": "6c1bb440151d61f7df20feceed2c6a66dd389191cc44d0284e1ed34cadd120f7", "timestamp": 1652703343.0467665}
# 	{"ECID": 23, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "98280859869cecf074702f6a60d939c21ddcbca87c4fd89d6ded57e126d63916"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0a389f2e842b878452f54e4479e24973510515acea2c021f15ee2ee77487eb92"}{"index": 24, "prevHash": "12e3f543bd29e4338b6fe9140a4188d214703e3c06d403b33e62f7e88588de56", "timestamp": 1652703343.112331}
# 	{"ECID": 24, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "36a6e3d1c4ac9babda773b7d118af3e28cb995cb6b4bc37fe695aaa6eb73dd1c"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "edcd0f494c55ac28036f7b06943980523bfdbbf80ac8039e766ba44348939b86"}{"index": 25, "prevHash": "b07398951eb9cb3a7c9c4fbb3b8f60c91073e12dcd6b622f44407e4837a4c24b", "timestamp": 1652703343.1774678}
# 	{"ECID": 25, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a6b0c690b54343731054612fcb7b7e50533d9e9e44c73352f213e58727eda526"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0339b23df605d984511bbd97cef72a2d0ae1e1f91742eb224cfb280f3b6568b3"}{"index": 26, "prevHash": "d331170043108364170c085011b513b10fc33f81e5106bf51d63ebf0cc846391", "timestamp": 1652703343.2411277}
# 	{"ECID": 26, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "27ab5572ce8402e6800f74a6d40875aad4f3d27161b360aff4c4abe39cbc9af3"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4e8ed3b6a18115a180af4f827d5c49f71370320ea8cf22774612426a7e7e9c0b"}{"index": 27, "prevHash": "e8e73c020f7580e932a052f903cd524e330c3d3e6331d94ff28ea431b4de0377", "timestamp": 1652703343.3108277}
# 	{"ECID": 27, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "b45e3641e11c964ade64947d789eaa136eb09ed4c075ca6c2ec2e966b38b4ce6"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "771721a2a25e62393f7d1a5b1430fb361dd688402c6f8c4593f195b96f30ff5c"}{"index": 28, "prevHash": "72f0480f7c78d4452b0cd94140aaa23aaf21d23a750d936555b4f4b90c60b9f3", "timestamp": 1652703343.3768992}
# 	{"ECID": 28, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "fe919919053c06aae161aa644514e07c66ed1e8db92c09f48a8a5e74164ea21b"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "ed3187af163e551bf749725aec535eb512cd737ad4939dfee048ad6796b72faf"}{"index": 29, "prevHash": "67ebe4ae768d23966b5c4df67f3e7ea4de7c3dfb469b11358ac90fae2d4badb0", "timestamp": 1652703343.4422052}
# 	{"ECID": 29, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a34b07d15d6645abb72a7720c37b0b8c94fa7d55dfc18622a437dec2e56a7a9b"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "22947cc3178dfd58cd0ad51717acc3cc9355d3520d7465690965213aabc952cf"}{"index": 30, "prevHash": "afd4539f16e6a005484089f9c27abc76714e08197eb092e0539aa5b6ff23ca64", "timestamp": 1652703343.530966}
# 	{"ECID": 30, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "322455d6faff2d007aea70f60b7ebdb5b7a264ac54d9f74abc397466c994319c"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1b0b18a38b67f5238d2ad3e1aeacfc48ce257f0ace948a72146f423724fa83d0"}{"index": 31, "prevHash": "0e8ac8c0bf215c95c452dced0f2041cd9a8faf8aaf6d4fb042dba29f94986433", "timestamp": 1652703343.6036294}
# 	{"ECID": 31, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "29784810d79839ae2d008558a65537e4ee510cc2be2ef8e66fd0f2c605aa78c0"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "7838268ee5e3584dfe09ddf65305f3de00219be58fa7b1d741f8cb2ade2b064c"}{"index": 32, "prevHash": "f9ac2e29cec09982ce557a7fae38aad5e006631f81b3d500742bde7a1799da39", "timestamp": 1652703343.669025}
# 	{"ECID": 32, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "29e3611f40c27e81ab42f44cf9c656374ad0fa8a91dc23b2c8afaec72f4214ba"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "c93f96c5a2ce4ab996fa2362126fef426eb405e1b1266731b5540cef78dc12b4"}{"index": 33, "prevHash": "5af3773cbeac686639ffbd827d8c814c7260fc9bd5eabfd90e4963b93dcd16b4", "timestamp": 1652703343.7335947}
# 	{"ECID": 33, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "6eef5bf6dc2b2aac37cdeb297cd0237acf04400e30936ba5da64380bcdd14d55"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "78aea1431faeade9d6a502a1b24ed3980036f593ec736ee3fbb85246d175cdd5"}{"index": 34, "prevHash": "a559e53cb9363be8e1ccbaa225d14170ffc442b09e162efa2eb88b68061256ac", "timestamp": 1652703343.799089}
# 	{"ECID": 34, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "84d71c651febb7ac8a53464dcdacde8d768ae9d7dc4765e9d737cbfc054fc20f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "29f6b4aaa950c3e1b792985cd5b579dc2d25c2d7a56aa6ad52f34f4396867742"}{"index": 35, "prevHash": "9a2b0b38fe090548a37205dda46ea003acfff42ec1089a419f7eb5fdb083dd14", "timestamp": 1652703343.8638625}
# 	{"ECID": 35, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "aa1e7bde6ef81bb39857157306c8b71c35469fb044c36a1404eaa71e6d3148cd"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1ee167c1b4c8dfd6af1478ab9d1f45fc516ec66bfab5a8a9a94678c18d4f90ae"}{"index": 36, "prevHash": "0ae586ab5488015ab0c416facfedff70ca5f58aa2873b6d067460302de4d4a10", "timestamp": 1652703343.936926}
# 	{"ECID": 36, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "3681efea5b6d2e86b645ce3f6d2de15c048606d25b72e2efcd03031534e3fa43"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "8fee8e8ef9489986cc8f38a80b91ef0069be9eb8256cb9039526c9febfc82142"}{"index": 37, "prevHash": "8e7ddd7385eff4a1397acdf5833d1c50099702e0d23e83846fc9dce414e92088", "timestamp": 1652703344.0009198}
# 	{"ECID": 37, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "ee47f5670bbd35547775a919fc1b87a5609c935a3c730df598b37fe55e9546e4"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "d108151d3441eecf07cae721bf6e3be534a3f7655622e5bd00c252ad09630b43"}{"index": 38, "prevHash": "eaa5cae2931934a707f04f73a3e6f0e19173ad780b024724ef244bca03ab57b1", "timestamp": 1652703344.0675747}
# 	{"ECID": 38, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "285c29ca3e77dc1c111c6bddbc6da53b3a9d003123ce7f74ab36471c13511d69"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "2bb1ecc0c2d819586e3e55f88fe2fc056baa99d89aa2b94ed53001fa45e0db14"}{"index": 39, "prevHash": "17b8242ac0ed00d6e8ac50277d6468981733e702cde91b822bfe78688601174f", "timestamp": 1652703344.1310499}
# 	{"ECID": 39, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "8326888d25b0ab1b9099de69db4319da9f591d72ba3d052e0575607a74d0b298"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "f31f38c4fde15c26d1783437d85ef15eadf628573e9ee55e544e971ffe8619f7"}{"index": 40, "prevHash": "1f5e27fb517547c4041ca37965e5c53d78ad23f2e97e39b0a499d0ea5dbd8ce0", "timestamp": 1652703344.1968937}
# 	{"ECID": 40, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "419ce99b65aa28607a0d8c2f7e2768ffcacdc667a4a6e3edb2a659e9cbae8b1e"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "2b716c7152fc09c030ea0583bd8e07880a2e877d338d78972f1527bb8c33b707"}{"index": 41, "prevHash": "952a0e6a3d8b57bebda7f979366be89bb3a680b10e28f6d481a4aa75f4cf43b7", "timestamp": 1652703344.2621522}
# 	{"ECID": 41, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "aa45c7b5a6aae86f9984d52e8a1d434daba051b3f5e3a473051711745b473a6f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "357e529ae2b213a1f6c490c8daa2006c3a62cdad7cc22e71dd38d3fc1e7a84d1"}{"index": 42, "prevHash": "06a327b72bb97c47cc49f7889d88364dd18fd40a115d9abf7ef8ad4e4f65c0c8", "timestamp": 1652703344.3255367}
# 	{"ECID": 42, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "1c9da36ad8afff5affbaee38fa4077288c008d93e8bf1c27cfebac23cee73aad"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "23e4a4b27635b1da96d2aded61af68acb6c2e6900402acae0ff8e9a21bc4f334"}{"index": 43, "prevHash": "460a7ec722327eee947ba73c635535e66de05f0d0c0056c16f8c69e3de939aec", "timestamp": 1652703344.3908007}
# 	{"ECID": 43, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a7300530d1731087f8201d0a9737eea03806166b593bff0b814a5f7aa21874f5"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "c6177ce3413a7d79496901dd161f2e9f634db0cd04c1b052f20f9b6107199406"}{"index": 44, "prevHash": "f9eb2ef25bc92582c30f870d3f1a839efe112b948ff93e6b1c9f85fe68f13a3a", "timestamp": 1652703344.4566243}
# 	{"ECID": 44, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "49599335edc9aad1ca6c836ae0e9aaa586f3b10c049492681951b665f9b84aac"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "6159aff1489b3c47081f4dbec91128a8e90fee56b114a5427d0294bf89836d4b"}{"index": 45, "prevHash": "b4c25623fcceb25b4810013c92fded06a020354eb20b4ac413d44b5b9a6da3ad", "timestamp": 1652703344.5364516}
# 	{"ECID": 45, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "bfcde2e9688fb8a8534534bd8280c996e895ac362766f5e91c0ea36539f08985"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a7f301ad7a56aa0dcdfc8e166e6d1323c2dd631d7dc5d82a6201146edd8127ce"}{"index": 46, "prevHash": "12d445fb86d2ff17c6e8c3f9f54c0b3f78747b8d4b39fd03c5f0137c00495075", "timestamp": 1652703344.602755}
# 	{"ECID": 46, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "dcfbec0d64aeb4c73c35b14f0037726f0e3fe81273a3a188e4d29df8c2d6cdc8"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "d5837355c55a03bf3f9c9c005923b5d51818759117827429d52d89c6ebc2ee52"}{"index": 47, "prevHash": "88c228ea440f6157812bdc300c5d9711368836592cfa71b0a7df7f6a38027ed8", "timestamp": 1652703344.6715076}
# 	{"ECID": 47, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "04a8329ca893956e2d15326ece89e01ca5f736fc54ccede15e5fa88219b35922"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a0abbe60cfe63652cc03b03c47d321a840cabc5f2f3845efb911b0e787cf2e71"}{"index": 48, "prevHash": "c3eed891bc768f9d3c5ccf9c181887015c6aeb92f1685afec8c2960e9748c4c6", "timestamp": 1652703344.7373714}
# 	{"ECID": 48, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "070c7681696f8cb82305125f7ebd7401fed2f43f2b7a32935949ad6c8414ad1d"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "47b80209218a4cd6c392df2fc64f3e006204743f3e8edb1ed7daad0eeb843ea5"}{"index": 49, "prevHash": "12ac18644c5b59e7ca1cf0bbfeb6c05ae8920fbb79ca4916c6b40e2624814ee5", "timestamp": 1652703344.802902}
# 	{"ECID": 49, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "448a4b45449a285c4ddd87f88ca46cd3bf3a325a8c7f02dbf768ae80808a864e"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e2a12e0b9f221c94ed10633deef2d577fc7c8771442a8aea9eaf310edc2c585d"}{"index": 50, "prevHash": "a587be0d2339609e5ff16d35698e251c6bf2c854d34dd5bff12e2f950a76ecad", "timestamp": 1652703344.8690152}
# 	{"ECID": 50, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a112a247ef2c44f64493812d2e1742cb6dc0d37a7782150cca4c0050ba3510cf"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "f32334327d3c03d3de7c6fdf37165f790779487d28b90dc610b063e0eb235f9d"}{"index": 51, "prevHash": "0a6a1d88760c36c3526f80fbad1f53a80bddc15090633585a2de8095b7757699", "timestamp": 1652703344.9376724}
# 	{"ECID": 51, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "f3f5f399759dad229ac7cecd089daa84db888f0c6a06f28675d400938236d41b"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b961a8eb5e6d661b997831efe404b4c847f0d4f3cd80aa8b07a1e0a078b48474"}{"index": 52, "prevHash": "e23a73594cfabbae16ad509e8fb9bc6240d5646a91633ab823a9db00354891d1", "timestamp": 1652703345.0019617}
# 	{"ECID": 52, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "20134644ff8478a80c88867e14e7d4d1b7ed64ef5d7a8b5e052db62d046654ab"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "5026d297680bdd6b1bba7ce9a66fd347f7ee4e0d2fb74aaf1aa419e2543ce638"}{"index": 53, "prevHash": "731425c0b726419cbe885e430174640e035bbc0b4f6f63c4212823f7c481fa74", "timestamp": 1652703345.0669644}
# 	{"ECID": 53, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "d0ae1551d3647ff1c9bf4e4114884c03aef782c4bfc339a6ce8c3ebe380678a1"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "2375dfabc73f6dc23d72ec31b431d4ae93a6fd2e85da0a682584a05fae3f72e0"}{"index": 54, "prevHash": "6620facb888c543cbc925557f18163fddab1425409bf5003ff5d3530f24e3838", "timestamp": 1652703345.140645}
# 	{"ECID": 54, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "ea3de2085aafd968ec553130b3e18dae081f2022dbac74dcaae5151a7f3e6336"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "3f0789ca4eef7acc91b776f8a3a9d3401fde4b20468a3532b2a9846b4630d9d4"}{"index": 55, "prevHash": "bdb5e01fbc496b5c7409a56c86ca2442e7e2a0def5d9028cc6811fcdf09eda0d", "timestamp": 1652703345.2041056}
# 	{"ECID": 55, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "594b39c7b3ce3dded38be02a338e82a6884755852e0324bbc3d912e35320d090"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "53110725a7c33334c21713edf408ae2217417ab825aa92ed37955587f7fe4362"}{"index": 56, "prevHash": "59ead3f0829dbae22840bf79d5ed5e3509656c000d96a56c883946fbdbacec01", "timestamp": 1652703345.2698627}
# 	{"ECID": 56, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "67d45a5220d67c3be8c3fbea61a5f8e6241b2082fd2ac2a4b89fda256d62d1fc"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "39a91f1750af32157c6d8242eb85c41f7c7473eb888e5b710db76cf282dca5a4"}{"index": 57, "prevHash": "fc0d2298845de404c07f5c8de2596d28ddb5bce8756eb8d7c094c950b1caebd0", "timestamp": 1652703345.333923}
# 	{"ECID": 57, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "46cec7e90486cb38fd78bbb9c2b8a03381a2f328066c19cf11a4e10ebfa9c673"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "40eb1cac2be5c1999e950a451093b8f2ef6d57562d15c82b15c1447eada5ed9c"}{"index": 58, "prevHash": "c3707b80671a042d7e428a1e16a1286c420eee4478c864ded68c8f2ef8647b47", "timestamp": 1652703345.3990972}
# 	{"ECID": 58, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "8b9b5e0044101f7b76bbe13b3ce824b789c300fcb3da1c47753ee885e7fec16f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "208472f19fee8df62b03ef7ee0dbfbe478c8f7b2b50a7cac044855602dc870d7"}{"index": 59, "prevHash": "fa09da6c8cb54f889d70787a1c82d6ad36624752185f6345ed352b411b6fe3e4", "timestamp": 1652703345.4636843}
# 	{"ECID": 59, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "e1c9cb39bf6570c03bb411030a80f36317cc4eecf30aeb01e083421cbb4c07ca"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "07857f7b86ff2e6867052b79c8ba65a4fd44680a05c16a1c774934bc1828a27e"}{"index": 60, "prevHash": "e79f5d030f659bbe4e09e800c2c5f00d6d3775ee79c3a94f72532dd613be47f7", "timestamp": 1652703345.5275028}
# 	{"ECID": 60, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "8c9d491ba5a5f1c81d1dd30aae846ed71e61562d6186378c4a2d17a25a82245d"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "6af00bbfabf2b58bb534d9689e9a59345dab495567fb9834a89bfa01146490b7"}{"index": 61, "prevHash": "efdd1728e557f3310c15fa8081b69cbafb3972070e928662a34d364586e2d32f", "timestamp": 1652703345.6019266}
# 	{"ECID": 61, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "a70556b6e094c14b4d4310cec6e50d74e894a9f38bbe87f5a27c644ae262f04c"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e725d685a4e213a1eca89b6f6e097541b83536df7123f2fc8586fa4fce6203cf"}{"index": 62, "prevHash": "0f11767f61ba7886661f6074c4071950a3a98fce33809448b89e305003722eb3", "timestamp": 1652703345.666462}
# 	{"ECID": 62, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "5d9436690d2ad45164e96949737a7415f047b7bb7ea3ed7cfccee828a28e026a"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4343408584ed502701eacbfa3cb35866d71bcf57de4158a58ef737ae605cf550"}{"index": 63, "prevHash": "43499ae35e0d1b2aa01a7ee186b0cf0cb958d960192d1cdbadf9802c66790926", "timestamp": 1652703345.7352078}
# 	{"ECID": 63, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "451b4c4085265716172a138b1c6a56b981a57a8a7b6d7df796f8ff2d948e61b0"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a154d2fa5b4fefe8eeac143145e5866c3f2bca75674ec51273ab3223dfd3a440"}{"index": 64, "prevHash": "598e697df0963414f4d162cd135939dcb47867230bf5ee733401d317575e6f19", "timestamp": 1652703345.7997139}
# 	{"ECID": 64, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "633e030d4b1dcff10bf0a65c98ecb800e8a9f717a1cb54bf54cb6427b143eeb5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "c0a4e3a3b4c80da76aca91d7048788d1e2ad2e8e0aa69bbbe495f132ac9b33b2"}{"index": 65, "prevHash": "17ac13afb66449ff2283e4e0f045abc0645f9cf13c791936c9f8dfeb19b217c3", "timestamp": 1652703345.862983}
# 	{"ECID": 65, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "f80d88ed3d38f3ef4ce9e7c080628e43596012508d1fe9ca3aecd0d8b98b6551"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0ff9b6b7b26a1c7da7b12f21b8cc1522cf306f6f0f5d665933d97683c9d83c91"}{"index": 66, "prevHash": "bdfa2aa1490800eaf341beee34d42fb2f6f93a36a38f5d675bf3b7119daa1e89", "timestamp": 1652703345.9301865}
# 	{"ECID": 66, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "f89b97ead25eb40a7c5b4be650cb3193b71c4ab3fa43102e824a0687e54654cd"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "25ade15f3ddea41fe14c02a635df211261d58f9186e021105abbf4e4750c0b4d"}{"index": 67, "prevHash": "ce61b0f3ae2c4301ad8c527fe1e4eb0353cebcec1abaf4b944455192ba3cd235", "timestamp": 1652703345.994335}
# 	{"ECID": 67, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "b172ec3517c9e0d7c6bef63452fe677c49f5bc468d83c0ee773fc886ecc15a86"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "5897b6586eadb562450ae2645e4d83dbefea606c6a282454a3780065a4c425a3"}{"index": 68, "prevHash": "45b4a391fb85bd931609400f73995615e6ee90eda26201ec8602b5638eb6f57a", "timestamp": 1652703346.0613177}
# 	{"ECID": 68, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "4bfd606d5ab960cb865eaca339b43f8af26c6c1e8758d9230f601bae13eaf835"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "00e87145ea00b9838e8a12ee23c688021bca80cba6a7f80f3b6db3029a2d0779"}{"index": 69, "prevHash": "6ed96e440df143e012ab5ed3d692f4e42632c376184fe35b9210d06144f5c38a", "timestamp": 1652703346.1261115}
# 	{"ECID": 69, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "299f62b008d221afc4732bccabfb975500a53e1e9de9d3678f03eec22dcf4faf"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "beb5af1e1f3914812a30641ab988c27322d4c338369db15a74902591498b2921"}{"index": 70, "prevHash": "567d1f1e40759e51408831235f533ad3312b76502dbbda5e0b6aace4f646768d", "timestamp": 1652703346.1913223}
# 	{"ECID": 70, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "dcd5670a0f3923dfaa324b023ebe603558eea083a5483d0a3556d50f3cb7b69a"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "239d9e0c2cf2419fe32b279d58c2e6544770728eba894a5133733d981136ac5c"}{"index": 71, "prevHash": "c1f555c94de09f9dc4175b93b175da3a630f50f13315f39d6f27961d9c4adebe", "timestamp": 1652703346.2551827}
# 	{"ECID": 71, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "879b3270bf88b6d09e7ea56c38e372c98a2d5942e52964519331110177b5694b"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "54e5ea4f15eeef3d4c619f4eb7ceea6f5307f9accb49a227352a6183d30632fb"}{"index": 72, "prevHash": "1e94f0bebccf6110355406d65a35d2cbc8efccf54bae7cb953cff7d8791d815c", "timestamp": 1652703346.32274}
# 	{"ECID": 72, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "3f724ef31a3ba3ec40b2ca9f1f802bb06d2448297fd0e185f90bbd1906abf8d2"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "dea0dd4073dbd96c689465944f9cac4d741c9cd99144d10502687f1660544ab7"}{"index": 73, "prevHash": "141fd1ab468994f6988363e20aa793101d15eec35f713275f8664c156193aefd", "timestamp": 1652703346.3873248}
# 	{"ECID": 73, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "5bb8bc9c0d66848b725e2b20e36c4164a8ac86e1602d564144ffb8bfb7e473f5"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "7e4b44a6d893e73101ad09c33a7c1342e28859ce33d481e1b8238287a14c5e21"}{"index": 74, "prevHash": "11828ab8ced8ce6161b30d819b234ddcb3fd5d4d80519cc7d976903be10a9078", "timestamp": 1652703346.451575}
# 	{"ECID": 74, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "e17d36ca3dfbdef07e13a9c6f760ca30734d3bfb0c6d91f92fbaa984d9bafafd"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a70f1dad54354d492c3e7134f73322cca484c928e78b5f0bd3ef5fa91cfbd956"}{"index": 75, "prevHash": "685bb94922b91f5e7170189fa848eceb553ed235c18409fa6e9b4e6e8065ebaf", "timestamp": 1652703346.5186682}
# 	{"ECID": 75, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "3773e24049b0b63fe82f34057909acf864b6ffd2e3fed75568eff68322374a4c"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "699be40a2e5354b132c4f68c35ebf63b160a474fad8ed661895fc1f01624fc20"}{"index": 76, "prevHash": "e4101dc0e19b2c3f2515861bd063fd4f2b30edf16a18509ef3d8f0e7ad48ad0d", "timestamp": 1652703346.5937088}
# 	{"ECID": 76, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "57d761b82206310aff1cc70e9653942296ddb6d9d6b2def39eaa6fc5d4f1dc3b"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b77edac17ce315f68e8831da480c97f081fe85d69bd2c936e4433fab3bea10e0"}{"index": 77, "prevHash": "c22d40f726991e8bd649a10bf7a6494c34aa15a6f535fd9e9160757700b0b767", "timestamp": 1652703346.6600199}
# 	{"ECID": 77, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "6dca8eb7a0cd1c3a9f5f593dfbfdbbdf884c922656dc39a77b3696db223b31ff"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b408458830f059f032eb43a123509336bb90a44905ef36290e1e7ec30716e6d6"}{"index": 78, "prevHash": "f5c5f294b4bb0b21fa0b980ca784b066743c461bf731134bcbd1f093ea1a2c76", "timestamp": 1652703346.7241497}
# 	{"ECID": 78, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "94cf1c6ec1c6a9474cc1673d4ae085c63ed7be308c97ca19cf6ac4e50ca30fdf"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1aaad6f195f24f60ffe08dc9ab470c4b9ba85546a7c5652d5c36139c97ef0c20"}{"index": 79, "prevHash": "1b8b937c22d9ba009624300606484fda1a0c65c4db960ac5e1d6ec0b1d442cd3", "timestamp": 1652703346.7881413}
# 	{"ECID": 79, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "287a7b6ac05504652a4866f515cf73731c5069ab77fbd5e0d4e1b7eeeebea6a5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "3a87c521e3d1c33dcd20e2d2595bcd94048e6d6c14f635ee4107a054cf04da7c"}{"index": 80, "prevHash": "bb72c7266c248bca7c0b9af2d484bdecbfc013c2e2f92a368137c6c6b298c624", "timestamp": 1652703346.8516374}
# 	{"ECID": 80, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "12a04b8a224fe0eb5599ba47306ed745a2d4ea2892b76dae5f9e4f20e12cbfd5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "84a2f0f1a40322558786cea56e24532e3ffb3f2b093989414e2439d84c6b3d69"}{"index": 81, "prevHash": "80397d9bca26f0bbe2574dd30b342be043dcd9b76943c1898b15b2f99c0973df", "timestamp": 1652703346.9210887}
# 	{"ECID": 81, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "110811fcf6af2bdb3b71645bab706778327f657568b991f418fef4a07f0c76db"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "6d41c8e28a442d22bb54b6c99f348375faaa3e79d7225e783d322727db1f4a7c"}{"index": 82, "prevHash": "7fd11255c68e4a2d7409a73c95b7515b88b30e86d30b790595dadaf319c08e1b", "timestamp": 1652703346.9852378}
# 	{"ECID": 82, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "e8e1d001dac9a6014d160755c29b22ce7e9d7a0591cc42f4cf3f731312759c9f"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "053b0fe1be5b33e417b805387ba5f01d346181ed92a9309a31aabd8fe733befa"}{"index": 83, "prevHash": "dc612fe8478e33eca9ac3158748da3bef21554eda60303fe24745e7dc3bf8c7a", "timestamp": 1652703347.0503647}
# 	{"ECID": 83, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "fe7a40a8f21d1ff527999c079d3a90726b8fdc149e28ddb551b2c450df76fd5a"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e6163f05a68a2861df92a16647cc14c55925b40a91821a26f6daa3ad5002bfdf"}{"index": 84, "prevHash": "0411efe6f841b3fdad54b7788575da1b74f2a0025cbae7c3c98e6bf9148b270a", "timestamp": 1652703347.1151931}
# 	{"ECID": 84, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "7c6262a9b372f4c957c6ba3e326fc73495adaba6af42d443d8bfba1c78c34de3"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "81d49748fe99cf9a944ddccc4f0e1c6f8f16658a4177ea9ea260b69a54f15c16"}{"index": 85, "prevHash": "031d7573eae07a9329f609a87107511d64b0345ef9e263dc87812b9bcca5c1c8", "timestamp": 1652703347.1827369}
# 	{"ECID": 85, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "cab48f2fd3eca38e6c02d6231ea95436eb07fa68d51e3d5a2dfdbcb6df9199d1"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "78d985a2140e6664a823ecfded3a2ba0663309acef8db1da08e60bd82c87a0b1"}{"index": 86, "prevHash": "85893a6adcff4b4811ee5a625028eac850f5b26d83468481de9ff9e5393c6ead", "timestamp": 1652703347.2474165}
# 	{"ECID": 86, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "c12ad72aebfc6d8ea1b7135a3868ab51d225cfa9b09ddaef4aade6c3da820836"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "d6d081350dd60a855f590f82c5ed0fa737ff944ffafeee9d38b89bafeaa695a3"}{"index": 87, "prevHash": "29860740f147c2bf56c7dc69fa31071d378b5bef1e3528f3daac16e836708505", "timestamp": 1652703347.310475}
# 	{"ECID": 87, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "c476c8236ed14ef9bfbc43783e1e3c3ff9921182b142d110d83602cebf4ac8f5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "73bdde2edaa83c86e265e590ed6f70b6c7ee1ec09c2c8d4a0205bbc0dfdf96f8"}{"index": 88, "prevHash": "713de4c35e544cc2f3edbc0422220e8331c799bef4c9c99254dba8c972f6e53c", "timestamp": 1652703347.3734195}
# 	{"ECID": 88, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "786473088335c8b221b7f9bee7c7a70a43ea8968d70d05c7d089f6df2feb9290"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "223b09db0251a0ddbc7813713964807bb489a1e7aa5b905a9f3a8f98412215ec"}{"index": 89, "prevHash": "e8c26af29aec7e3ee7936973ce602472702ceb46feaf79ad9ef2fea8f671eb29", "timestamp": 1652703347.4369256}
# 	{"ECID": 89, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "2b6c3b448c42cdcd02622b627907b98b2ccb042aa4e629dc783fab436d576dd5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0bfaff7e569230818bde62b1c7c0d719f5d54c1abe10f42ea42e9a8f22b57b14"}{"index": 90, "prevHash": "fa633df21b2b04308dd633ebeacb52aad023aff8c3338702eb8079ec0ec391d9", "timestamp": 1652703347.50227}
# 	{"ECID": 90, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "85f576e606cd87902407a100f9af240a70130d007d4726693066368a0919c5ea"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "651571f7798be3d9a5642f7381fdcb230e2fc1908a501f3be77bb633826ccbbf"}{"index": 91, "prevHash": "aa727a3c732e9f61902e6956a3a1de0b9c68a56e8aaa7693b95e105afd8f1f05", "timestamp": 1652703347.5677626}
# 	{"ECID": 91, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "80208dfa8450b2708d18ef9a0c7b663e23452128889d02180fca917fd7bd276d"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "516573f54ffc05b4fec333a7e62dfe1b43021265a0c77f09f539b107ef90b740"}{"index": 92, "prevHash": "d80466141a73d9a58dfda044f2c610f72d2887e09da082d517ddd4adea4d84ab", "timestamp": 1652703347.6420765}
# 	{"ECID": 92, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "0c911881afffbb560c15ed24cc5f5919cc668edefb38c3110dab038537251542"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "2546049636c5c4fb887d177cefa86cfd2edafe671fbab32d92845791c7bb2c9e"}{"index": 93, "prevHash": "d21c07430f3409be0136638e8438fb290bc12c609f3e4ca106166a573a0cfa0b", "timestamp": 1652703347.7124677}
# 	{"ECID": 93, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "d4791cdbd4a08880e8b4d8e278fccc56c9bbf5d4ee59159891725fa398aff8e2"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "06eae244a40ae49d8a02f46059328473a3ac74dbb5765391eebd87a6161b9a94"}{"index": 94, "prevHash": "227ccdcfe4f519421319112f2dbe5ebe007a868b588e248b3fa52185bb86ac3a", "timestamp": 1652703347.7843163}
# 	{"ECID": 94, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "9b48ccf2f2529b8b7e347917ad67e1c07f0b58d6e7e78b240643331df1f3ead5"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "34ef8b267401d45c77fbb02c81ef6972dc0d3eaf69946da0f6e95bdec82ee1b9"}{"index": 95, "prevHash": "ca7a3283977c0c12cc25036aacdaaa0d667bd41c752951de1eb124db3e486632", "timestamp": 1652703347.8504949}
# 	{"ECID": 95, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "cd40af7db007e110b5c7d7dc6aa199a5a0470c1c220fa06eac005a6318047762"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "9f107f86d2828f2026dc8923a9cd64baa382442d72c4c9f598acfbda0c9cbde8"}{"index": 96, "prevHash": "ea7daedadfba0a5df6dd6a6883d414272d4349cbdee18fcc2b396c35bf944539", "timestamp": 1652703347.9144812}
# 	{"ECID": 96, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "0333e81f70023d52b54815e80b6ae194d243c59bbefc2856ce3a808f06c62c39"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "52cd46af1ff0ff7a271ba6ad090074eef0f9acd46a1a8475b5377ee54c9b45eb"}{"index": 97, "prevHash": "5a585cf8d56d73ade614c2710254c7b913ead75ff6c35924c49108342d3937d3", "timestamp": 1652703347.9812891}
# 	{"ECID": 97, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "c49cc38b0db44beb819fed048b551a77658b007e49cfc53a90e86770166861a9"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "75cae744860b2ec1b70eecc107d2505b765774aff1371825be9f282bef60faa4"}{"index": 98, "prevHash": "e38268abc179784a0f0897ff872961429669dff7ac72b49cff1b4cdc993e62f2", "timestamp": 1652703348.0466478}
# 	{"ECID": 98, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "2775e49b446a6603aa93fa976f19d9d4e2db2fa3897b7c77ee7a550d3cc595e9"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b99974d09edb68bb2b18c069bf873daf5b8ac8d89a86822e0dd49f9d0a0ceac4"}{"index": 99, "prevHash": "47d0d1769529a4f9086371296491d407a03d1344d8cb4a166c5d16b965868cd6", "timestamp": 1652703348.117329}
# 	{"ECID": 99, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 0}{"keyEncr": "...", "keyHash": "c9594ba85584f7c3dcf9b232dccc84dc6677a81c7a0277e84c5de9de83efd366"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4411c237b3d1fee51f33258b6bcbeddebadcd252d867d520275b04986f549e14"}{"index": 100, "prevHash": "c3420b22991a4ab493e469b697d8dbc4a5ae8798fe09ac32bf19b3810148f542", "timestamp": 1652703348.182928}
# 	{"ECID": 1, "PID": null, "SID": null, "netHash": null, "stage": 1, "status": 1}{"keyEncr": "...", "keyHash": "6900de6fc06868760e936d10515704ff5d921dc4b58caf615633cd0e0728673d"}{"address": "Owner 0", "publicKey": "..."}{"signature": "...", "trnsaxnID": "182216ba2c4579c6fee6baec9bba9f343588a4756339796ff76bc0f23555ab77"}{"index": 101, "prevHash": "61c0516ccb0be20bac5b80d121a0c7253a914ce85376c3cc559f321f3fc52d7b", "timestamp": 1652703348.2778447}
# 	{"ECID": 0, "PID": null, "SID": null, "netHash": null, "stage": 2, "status": 0}{"keyEncr": "...", "keyHash": "2b51d5ed0004d0187a2411d409735253e5045f87c1d858a3068af16cf01b3b6f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a9c65f478ec03a37d633697500f35067e3d827675e9d80f2d371ea73db548f75"}{"index": 102, "prevHash": "829858c1453f14e90b9c180551b3d0061f22351d64ab1c4fc332dd3f3bb45778", "timestamp": 1652703348.3672204}
# 	{"ECID": 3, "PID": null, "SID": null, "netHash": null, "stage": 2, "status": 0}{"keyEncr": "...", "keyHash": "207f5f7fd64fc3e3bc1f8591a66f9da23f1fcc54e6b917f44c4c6709e82b7e90"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "66769bfdf461221fbcf657ac254e3fad01fe10076362639022e630c135055733"}{"index": 103, "prevHash": "162c880c456963210cb1d5dbd56c03317e37a24302f319f0be832b55629bd351", "timestamp": 1652703348.430437}
# 	{"ECID": 6, "PID": null, "SID": null, "netHash": null, "stage": 2, "status": 0}{"keyEncr": "...", "keyHash": "682a4bfe45e0ed1dc289d552e60687e476e7b84e0c19fe5532926b28c191faba"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1a04108501cf0c6bd79b0105df039950f7031722650844afe9ecbee2b3874a01"}{"index": 104, "prevHash": "ea96a4dace2e8da655923b563431e9858abbea9813a60bfe8402f8d0bcc4824d", "timestamp": 1652703348.4953198}
# 	{"ECID": 7, "PID": null, "SID": null, "netHash": null, "stage": 2, "status": 0}{"keyEncr": "...", "keyHash": "c475df1a6a0d6c3f8e5426cb53cd3bb84525bb1277778eb158c6f9e41620c0a5"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "43203412a1222e707447becdaca6d67861896b264f853b99cc1f2b76d9b9d0a8"}{"index": 105, "prevHash": "6b44572ee950e34a107b04ed4335b15e5e4a99570971e917f187dec256cfef01", "timestamp": 1652703348.5681825}
# 	{"ECID": 11, "PID": null, "SID": null, "netHash": null, "stage": 2, "status": 0}{"keyEncr": "...", "keyHash": "bcc3bb25d9b9c974efb9c503c58b7c539d3df48d94888aed0d08cfa0d83a202f"}{"address": "Owner 1", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a5947132390894bab12301d69d950eb838dbb4aa3d867c4f7863bbf3e6617864"}{"index": 106, "prevHash": "0c0e9a842f108ba31d07afc1c0519403e7ed35b40b174edf1f0626356ec6df9b", "timestamp": 1652703348.641965}
# ...
# 	{"ECID": 59, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "e1c9cb39bf6570c03bb411030a80f36317cc4eecf30aeb01e083421cbb4c07ca"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "6e2bb783a4f0e8a6e5873ae34d99eed372acd216a989ec1abe220c900dbbc633"}{"index": 375, "prevHash": "e372d9009637b399c2413f0c5facfacbf7287fb98acb3089c5a8a06f34725d4f", "timestamp": 1652703379.5780988}
# 	{"ECID": 60, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "8c9d491ba5a5f1c81d1dd30aae846ed71e61562d6186378c4a2d17a25a82245d"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "613212a5564e8524a6049be0252f5cdff408b27f93c4aeabd3fc1573a90628e7"}{"index": 376, "prevHash": "fa2bd94efdbee253fe6ec5dbbee34074ac93d65f289cbcc6d71f1fd4ef5837ed", "timestamp": 1652703379.57828}
# 	{"ECID": 62, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "5d9436690d2ad45164e96949737a7415f047b7bb7ea3ed7cfccee828a28e026a"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "3a5e2370944d3ca89441f02f0ae15c5a9fe9a415af15a76c5feffba5e1f59570"}{"index": 377, "prevHash": "3c9de50751a97196fdb95f1d145844982ca61ebe5e0aff863d84e6074ec64603", "timestamp": 1652703379.578453}
# 	{"ECID": 63, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "451b4c4085265716172a138b1c6a56b981a57a8a7b6d7df796f8ff2d948e61b0"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0c330a95507dc8b156f91499807bb8c1ae4e24cfaa4fd6b27073da3125a70444"}{"index": 378, "prevHash": "0c191f07a7ca7b50d5f85d407b73f40900d3cf73fe987ba36e8043b98e56bd0c", "timestamp": 1652703379.578628}
# 	{"ECID": 64, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "633e030d4b1dcff10bf0a65c98ecb800e8a9f717a1cb54bf54cb6427b143eeb5"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "7c92418a4ab66a03a88f6c888846a1e4ae5a8b62342c96bfd14136304773b1f0"}{"index": 379, "prevHash": "8c15106303c5332b4d132439f3ec2053eab2b59d0e032a06edbf7e1811149a26", "timestamp": 1652703379.578802}
# 	{"ECID": 66, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "f89b97ead25eb40a7c5b4be650cb3193b71c4ab3fa43102e824a0687e54654cd"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "20850ecfc859b3d1a699297aa4fb15d572f83a4af159dcb029374c44d6950bfd"}{"index": 380, "prevHash": "63c54666198f2b748da1c83eccf5425f42faf12065eb4ad6373e53c4b916c409", "timestamp": 1652703379.5789843}
# 	{"ECID": 71, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "879b3270bf88b6d09e7ea56c38e372c98a2d5942e52964519331110177b5694b"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "90f0ce4ea2b3a945f761c2d089b474294edd4c2509c33707c5ec7cae8d07c60d"}{"index": 381, "prevHash": "dbac4f602a23015ed82c5b74083e8256cd16be97edfe372bff0d13cf8c560107", "timestamp": 1652703379.5791588}
# 	{"ECID": 74, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "e17d36ca3dfbdef07e13a9c6f760ca30734d3bfb0c6d91f92fbaa984d9bafafd"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "1caba7af47c6965dca76b537b5ca584c627a1e582fac4f7f9c2114afe11cc6b1"}{"index": 382, "prevHash": "c00aa96152c26ccee03024fcf79091996953abeda405022d7412a090ada06093", "timestamp": 1652703379.57935}
# 	{"ECID": 75, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "3773e24049b0b63fe82f34057909acf864b6ffd2e3fed75568eff68322374a4c"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "63904470d96cf6c8d8564d406ba44135333c897f19054245ce6bc2cffb688f1f"}{"index": 383, "prevHash": "9fd4db3e3f1d75457738f6b135d1cf25c9a9fe653f292d56cbefdf7d12191bc2", "timestamp": 1652703379.5795255}
# 	{"ECID": 79, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "287a7b6ac05504652a4866f515cf73731c5069ab77fbd5e0d4e1b7eeeebea6a5"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "babdcd789560bf3c7798db7786a1a248e43cf0fba7c8fda2233d478caf4f156d"}{"index": 384, "prevHash": "8378b752de4c39f9b77aac32cfb182dfb79298676848fac011d867a5a4715cf7", "timestamp": 1652703379.5797045}
# 	{"ECID": 80, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "12a04b8a224fe0eb5599ba47306ed745a2d4ea2892b76dae5f9e4f20e12cbfd5"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "7d900779352c929bee03b45ced96a33efae88c11fb499584406c262781ddc09b"}{"index": 385, "prevHash": "8a1be51c145a086b239cf5a518c20e2443470438e0c790abc3dd9c24652b37e2", "timestamp": 1652703379.5798857}
# 	{"ECID": 81, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "110811fcf6af2bdb3b71645bab706778327f657568b991f418fef4a07f0c76db"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4a2e969a819d35472be8daa8fbad83207a4d559567e7d83e2bd869712b867822"}{"index": 386, "prevHash": "15c3ecf1770935f57e2fc0d3ce14f9d75257fc92cdebbd8ba494929d99b5b06c", "timestamp": 1652703379.5800617}
# 	{"ECID": 83, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "fe7a40a8f21d1ff527999c079d3a90726b8fdc149e28ddb551b2c450df76fd5a"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "887f9dc92a1c8ba1891792a21ff887033d4ab61fb851ecee0fcf9f58cb227b4a"}{"index": 387, "prevHash": "5c1ae5a7129606f1e7fe9e9f87d4cc7a3cd9011853596ec5f92dc7aa5ee9570a", "timestamp": 1652703379.5802345}
# 	{"ECID": 86, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "c12ad72aebfc6d8ea1b7135a3868ab51d225cfa9b09ddaef4aade6c3da820836"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "47098cabb9eca80b6d619755761688617db4cc83fb7458abe6d708e00a4dd6c0"}{"index": 388, "prevHash": "bfb4ac3e051eefdf15309d14bf74bd091853d2335e0bf97725cbc2baf3c71ffc", "timestamp": 1652703379.5804195}
# 	{"ECID": 87, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "c476c8236ed14ef9bfbc43783e1e3c3ff9921182b142d110d83602cebf4ac8f5"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "3f724357de3bc031b0842e18c04b8af9e6753c45f3b4b827528c9adbbde2798a"}{"index": 389, "prevHash": "4db19f8175883f7d9f321d346b8187e9ef030043eed360cd0e2da287e3830098", "timestamp": 1652703379.5805936}
# 	{"ECID": 88, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "786473088335c8b221b7f9bee7c7a70a43ea8968d70d05c7d089f6df2feb9290"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "4b0f9434792560d1e81ee47e0d0f602b5e43bd9b7347838da4d12fb7adc3fa21"}{"index": 390, "prevHash": "941d54d45be828d1a4fc328631cc02675e9a7a158060ac60335bfbbe49e20522", "timestamp": 1652703379.5807664}
# 	{"ECID": 89, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "2b6c3b448c42cdcd02622b627907b98b2ccb042aa4e629dc783fab436d576dd5"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e50e759a26d6736c78afd8b81a7b4e85d07ba52f61aebbb48725b2efda8cc983"}{"index": 391, "prevHash": "6d6acd7b920e0e4db830d7890f634e610254aed9db54c602733bcc4e9ae805b6", "timestamp": 1652703379.5809438}
# 	{"ECID": 90, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "85f576e606cd87902407a100f9af240a70130d007d4726693066368a0919c5ea"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "b48ac26a94c18a76115fea9f325d16830c35637445d90ea6ca728475d79d38eb"}{"index": 392, "prevHash": "a61dda65a538980daaf0a66414ddbe324612704eb99981771d0496934b58faf8", "timestamp": 1652703379.581118}
# 	{"ECID": 95, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "cd40af7db007e110b5c7d7dc6aa199a5a0470c1c220fa06eac005a6318047762"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "fb15a4df3616bb348b5d347bd77b0f2d866143b7f9a114f6172d9cd0277ee58d"}{"index": 393, "prevHash": "e16e3de179f50b4afc2f3bb3dbfd4a133f26d2b085e0c60a22493ded98484077", "timestamp": 1652703379.5813012}
# 	{"ECID": 97, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "c49cc38b0db44beb819fed048b551a77658b007e49cfc53a90e86770166861a9"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "e9c0094ab311b3fa97de87ad67eb3813c39e437007c6141b888a0e2312ee2712"}{"index": 394, "prevHash": "76ebdf6a162165b499301eaecb0e4fa2315f37bdc71d53f9461dd12e1144e9d1", "timestamp": 1652703379.5814762}
# 	{"ECID": 98, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "2775e49b446a6603aa93fa976f19d9d4e2db2fa3897b7c77ee7a550d3cc595e9"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "a7e68c8fb7c4cb9c0d60812592cdaf9c68607be26f2b9935991b8849afad75c1"}{"index": 395, "prevHash": "b7603d39b2c7229cca8ea187eb524338f7eb34c63c5cc9df821f693fa5669483", "timestamp": 1652703379.5816483}
# 	{"ECID": 99, "PID": "c0f0e113fcc871e90826a572931225b9dcbe751a91943ba839995324300be35d", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "c9594ba85584f7c3dcf9b232dccc84dc6677a81c7a0277e84c5de9de83efd366"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "91f386f2977c043e99ddbbe6a7814d4a7ad7438d31e8c3d1e63db316d069eb7f"}{"index": 396, "prevHash": "b4995d7d56ad7f8de3fd0cfbefd9cabaf8347df76bdfdcbbc7e8bfaaf57d2e42", "timestamp": 1652703379.5819778}
# 	{"ECID": 100, "PID": "0421b838850b58855b80744dc90df82519d378dbd885dc412d11185811db2135", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "1353a2edc8be43ebf76d4d1b929bb0729f04eca5eee562854938aa338ff49adb"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "90024e940d1802af036a9e7498486a0ff881c63534d4088f1cd197d19a8cf8d0"}{"index": 397, "prevHash": "e0e674b21e339b03ca25067e11c6c605a8ba61742c6326f27ca5cadf56b279e7", "timestamp": 1652703379.5821683}
# 	{"ECID": 101, "PID": "0421b838850b58855b80744dc90df82519d378dbd885dc412d11185811db2135", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "ac68885a1296522aaa02aeb9f2733d50fccf0e4d185e19f5a28a6596595fa5c7"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "ba9ab4a1676b5f423899baed84150b5b3a97a267cad1893c9d9716eedb55f184"}{"index": 398, "prevHash": "f18993231615d6991ae8296e54c0de6bd4f4ab36bb0f17e1f828180616157563", "timestamp": 1652703379.5823584}
# 	{"ECID": 102, "PID": "0421b838850b58855b80744dc90df82519d378dbd885dc412d11185811db2135", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "06cfb6f5068b86c2d529cbf52c67766434677f0710ef3a975abc15e4bd69b0e1"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "0da6056432cb9e3f913cba5b0ba36c0d7f2674c06fd6aa4ffd6a83dfa273d346"}{"index": 399, "prevHash": "f1fe55889cc014c8a599f2bcbcc99c7adb372d0661fd14d0ace41f449a5cff6c", "timestamp": 1652703379.5825398}
# 	{"ECID": 103, "PID": "0421b838850b58855b80744dc90df82519d378dbd885dc412d11185811db2135", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "127fb95ee20d176ed26a91dd058a9768e64851bc2b6f08f9e5595588c7ed82a9"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "f2558c38a312742bc1316b7c7019ab54af67e63bb86e39bdde4c84a633b7d099"}{"index": 400, "prevHash": "c25f9006b3c3c49b6aba771d79d89aa92e60edc9c79953fa9d1ebddfc1e5b7f6", "timestamp": 1652703379.5827131}
# 	{"ECID": 104, "PID": "0421b838850b58855b80744dc90df82519d378dbd885dc412d11185811db2135", "SID": "4583584f73bf8037ee5e3e54d776e5c4d5bebb8070fb89c7c85f09cb0b4028e2", "netHash": null, "stage": 3, "status": 0}{"keyEncr": "...", "keyHash": "6c74595f50b73deb41aaf17d020c4fcc0034084f6e8e0b72fcef9978a332826a"}{"address": "Owner X", "publicKey": "..."}{"signature": "...", "trnsaxnID": "690ee39c512f6319a771d4256c890729005b619de7479bff20e5cbf316ea8388"}{"index": 401, "prevHash": "c471152b01b72955f737095b02644c71da43581eafa1ea76cddf50805bc8968a", "timestamp": 1652703379.5828936}
# ]
